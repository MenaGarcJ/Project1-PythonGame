# %% [markdown]
# <a href="https://colab.research.google.com/github/MenaGarcJ/Project1-PythonGame/blob/main/Hangman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##bienvenido

# %%
import random

fiction_characters = ['Anakin','Frodo','Sam','Obiwan','Aragon','Legolas','Batman','Flash','IronMan','Thor','Rocket'
             , 'Spiderman','Thanos','Loki','Vision','QuickSilver','Ultron','Robin','Aquaman','Antman','Groot']

def get_word():
    word = random.choice(fiction_characters)
    return word.upper() # Se utilizará el método upper para poder validar 

def play(word):
    word_completion = '_' * len(word) # Calculará el número de espacios multiplicando el caractér por la longitud de la palabra
    guessed = False # Servirá para poder inicializar el juego y servirá como condicional 
    guessed_letters = [] # Guardará las letras que se vayan adivinando
    guessed_words = [] # Guardará las palabras que se vayan adivinando
    tries = 6 # Cada intento corresponderá a las partes del cuerpo del kemonito
    
    # Se desplegará el mensaje de bienvenida y las instrucciones
    print('¡Bienvenido IronHacker! ¡Juguémos ahorcado!')
    print('\n')
    print('''
    Instrucciones: Deberás completar la palabra antes de agotar tus intentos. \n
    Tendrás un total de 6 intentos y las palabras tienen el nombre de diversos personajes ficticios. \n
    Finalmente, los intentos podrán ser por letra o bien, directamente la palabra. \n
    Los fallos se contabilizarán igual. 
    ''')
    print('\n') 
    while not guessed and tries > 0: # Este while correrá el juego mientras guessed sea false y tries mayor a 0
      guess = input("Ingresa la letra o palabra: ").upper()
      if len(guess) == 1 and guess.isalpha(): # Este if evaluarça si es una letra el input
        if guess in guessed_letters: # Aquí busca si el guess se encuentra ya dentro de la lista de letras 
          print("Ya has adivinado esta letra.", guess)
        elif guess not in word: # En caso de que no, este elif le restará un intento e imprimirá el mensaje de fallo
          print('Opps', guess, 'no se encuentra dentro de la palabra.')
          tries -= 1
          guessed_letters.append(guess) # Al final se agregará la letra adivinada a la lista vacía de guessed_letters
        else:
          print('Buen trabajo', guess, 'está dentro de la palabra!')
          guessed_letters.append(guess) # Se agregará la letra adivinada a la lista vacía de guessed_letters
          word_as_list = list(word_completion) # convertirmos word_completion a lista
          indices = [i for i, letter in enumerate(word) if letter == guess] # Este list comprehension nos servirá para iterar sobre word_completion y poder evaluar por índices
          for index in indices: # evaluamos el index en indices (que es word_completion hecho list comprehension)
            word_as_list[index] = guess
          word_completion = ''.join(word_as_list) # Si se encuentra se agregará de nuevo como string
          if "_" not in word_completion: # Con este if revisaremos si el caractér "_" se encuentra dentro de word_completion, en caso de que sea verdadero significará que acabó el juego; el usuario habrá adivinado
            guessed = True
      elif len(guess) == len(word) and guess.isalpha(): # este elif evaluará si la longitud del input es igual al de la palabra, en ese caso evaluará el guess como la palabra entera
        if guess in guessed_words: # pasará a este if en donde, al igual que con la letra, evaluará si la palabra ya se encuentra en la lista de palabras adivinadas
          print('Ya has adivinado la palabra', guess)
        elif guess != word: # en caso de que guess sea diferente a la palabra, se restará un intento y se agregará el guess en la lista de la palabra
          print(guess, "no es la palabra :(")
          tries -= 1 
          guessed.words.append(guess)
        else:
          guessed = True
          word_completion = word
      else: # Este else cacha todo lo demás del input del usuario, pero no le cuenta como intento
        print("No es un intento válido, por favor, inténtalo nuevamente")
      print(display_hangman(tries))  # estos prints, le darán visualización al usuario para que vea su avance
      print(word_completion) # estos prints, le darán visualización al usuario para que vea su avance
      print("\n")
    if guessed: # Este if se ejecutará al momento de que una de las dos condiciones del while se deje de cumplir
      print("¡Felicidades!  ¡Has adivinado la palabra correctamente!")
    else:
      print('¡Que mal! Te has quedado sin intentos, la palabra era: ' + word + ", tal vez la siguiente!")

def display_hangman(tries): # Los stages del hangman están guardados en una lista, dentro de esta función. El índice de cada stage del hangman, corresponde el número de intentos que le quedan al usuario
    stages = [  # Ya estas muerto: cabeza, torso, y todas las extremidades
                """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     / \\
                   -
                """,
                # cabeza, torso, ambos brazos y una pierna
                """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     / 
                   -
                """,
                # cabeza, torso, y ambos brazos
                """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |      
                   -
                """,
                # cabeza, torso y un brazo
                """
                   --------
                   |      |
                   |      O
                   |     \\|
                   |      |
                   |     
                   -
                """,
                # cabeza y torso
                """
                   --------
                   |      |
                   |      O
                   |      |
                   |      |
                   |     
                   -
                """,
                # cabeza
                """
                   --------
                   |      |
                   |      O
                   |    
                   |      
                   |     
                   -
                """,
                # Estado inicial
                """
                   --------
                   |      |
                   |      
                   |    
                   |      
                   |     
                   -
                """
    ]
    return stages[tries]


def main(): 
    word = get_word()
    play(word) 
    while input("Otra o te pandeas? (S/N) ").upper() == "S": # Este while le dará la opción al usuario de jugar de nuevo
        word = get_word()
        play(word)


if __name__ == "__main__": # Permite correr la función main dentro de la línea de comando
    main()
# Out:
# ¡Bienvenido IronHacker! ¡Juguémos ahorcado!
#
#
#
#     Instrucciones: Deberás completar la palabra antes de agotar tus intentos.
#
#     Tendrás un total de 6 intentos y las palabras tienen el nombre de diversos personajes ficticios.
#
#     Finalmente, los intentos podrán ser por letra o bien, directamente la palabra.
#
#     Los fallos se contabilizarán igual.
#
#
#
# Ingresa la letra o palabra: [1,2,3,4]
# No es un intento válido, por favor, inténtalo nuevamente
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# ______
#
#
# Ingresa la letra o palabra: 3.1416
# No es un intento válido, por favor, inténtalo nuevamente
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# ______
#
#
# Ingresa la letra o palabra: %&$
# ...
